# %% [markdown]
# # Parts of Speech Assessment

# %% [markdown]
# For this assessment we'll be using the short story [The Tale of Peter Rabbit](https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit) by Beatrix Potter (1902). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/14838.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

# %% [markdown]
# **1. Create a Doc object from the file `peterrabbit.txt`**<br>
# > HINT: Use `with open('../TextFiles/peterrabbit.txt') as f:`

# %%
doc = None
with open('../TextFiles/peterrabbit.txt') as f:
    txt = f.read()
    doc = nlp(txt)

# %% [markdown]
# **2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.**

# %%
# Enter your code here:

ctr = 0
for sentence in doc.sents:
    ctr += 1
    if ctr % 3 == 0:
        for token in sentence:
            print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# They       PRON     PRP    pronoun, personal
# lived      VERB     VBD    verb, past tense
# with       ADP      IN     conjunction, subordinating or preposition
# their      PRON     PRP$   pronoun, possessive
# Mother     NOUN     NN     noun, singular or mass
# in         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# sand       NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# bank       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# underneath ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# root       NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
#
#           SPACE    _SP    whitespace
# very       ADV      RB     adverb
# big        ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# fir        NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# tree       NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# Then       ADV      RB     adverb
# old        ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# Mrs.       PROPN    NNP    noun, proper singular
# Rabbit     PROPN    NNP    noun, proper singular
# took       VERB     VBD    verb, past tense
# a          DET      DT     determiner
# basket     NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# her        PRON     PRP$   pronoun, possessive
# umbrella   NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# went       VERB     VBD    verb, past tense
# through    ADP      IN     conjunction, subordinating or preposition
#
#           SPACE    _SP    whitespace
# the        DET      DT     determiner
# wood       NOUN     NN     noun, singular or mass
# to         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# baker      NOUN     NN     noun, singular or mass
# 's         PART     POS    possessive ending
# .          PUNCT    .      punctuation mark, sentence closer
# First      ADV      RB     adverb
# he         PRON     PRP    pronoun, personal
# ate        VERB     VBD    verb, past tense
# some       DET      DT     determiner
# lettuces   NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# some       DET      DT     determiner
# French     ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# beans      NOUN     NNS    noun, plural
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# then       ADV      RB     adverb
# he         PRON     PRP    pronoun, personal
# ate        VERB     VBD    verb, past tense
#
#           SPACE    _SP    whitespace
# some       DET      DT     determiner
# radishes   NOUN     NNS    noun, plural
# ;          PUNCT    :      punctuation mark, colon or ellipsis
#
#
#          SPACE    _SP    whitespace
# And        CCONJ    CC     conjunction, coordinating
# then       ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# feeling    VERB     VBG    verb, gerund or present participle
# rather     ADV      RB     adverb
# sick       ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# went       VERB     VBD    verb, past tense
# to         PART     TO     infinitival "to"
# look       VERB     VB     verb, base form
# for        ADP      IN     conjunction, subordinating or preposition
# some       DET      DT     determiner
# parsley    NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# He         PRON     PRP    pronoun, personal
# lost       VERB     VBD    verb, past tense
# one        NUM      CD     cardinal number
# of         ADP      IN     conjunction, subordinating or preposition
# his        PRON     PRP$   pronoun, possessive
# shoes      NOUN     NNS    noun, plural
# among      ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# cabbages   NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# other      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# shoe       NOUN     NN     noun, singular or mass
#
#           SPACE    _SP    whitespace
# amongst    ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# potatoes   NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# Peter      PROPN    NNP    noun, proper singular
# gave       VERB     VBD    verb, past tense
# himself    PRON     PRP    pronoun, personal
# up         ADP      RP     adverb, particle
# for        ADP      IN     conjunction, subordinating or preposition
# lost       VERB     VBN    verb, past participle
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# shed       VERB     VBD    verb, past tense
# big        ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# tears      NOUN     NNS    noun, plural
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# but        CCONJ    CC     conjunction, coordinating
# his        PRON     PRP$   pronoun, possessive
# sobs       NOUN     NN     noun, singular or mass
# were       AUX      VBD    verb, past tense
#
#           SPACE    _SP    whitespace
# overheard  VERB     VBN    verb, past participle
# by         ADP      IN     conjunction, subordinating or preposition
# some       DET      DT     determiner
# friendly   ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# sparrows   NOUN     NNS    noun, plural
# ,          PUNCT    ,      punctuation mark, comma
# who        PRON     WP     wh-pronoun, personal
# flew       VERB     VBD    verb, past tense
# to         ADP      IN     conjunction, subordinating or preposition
# him        PRON     PRP    pronoun, personal
# in         ADP      IN     conjunction, subordinating or preposition
# great      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
#
#           SPACE    _SP    whitespace
# excitement NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# implored   VERB     VBD    verb, past tense
# him        PRON     PRP    pronoun, personal
# to         PART     TO     infinitival "to"
# exert      VERB     VB     verb, base form
# himself    PRON     PRP    pronoun, personal
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# Mr.        PROPN    NNP    noun, proper singular
# McGregor   PROPN    NNP    noun, proper singular
# was        AUX      VBD    verb, past tense
# quite      ADV      RB     adverb
# sure       ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# that       SCONJ    IN     conjunction, subordinating or preposition
# Peter      PROPN    NNP    noun, proper singular
# was        AUX      VBD    verb, past tense
# somewhere  ADV      RB     adverb
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
#
#           SPACE    _SP    whitespace
# tool       NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# shed       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# perhaps    ADV      RB     adverb
# hidden     VERB     VBN    verb, past participle
# underneath ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# flower     NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# pot        NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
# Mr.        PROPN    NNP    noun, proper singular
# McGregor   PROPN    NNP    noun, proper singular
# was        AUX      VBD    verb, past tense
# after      ADP      IN     conjunction, subordinating or preposition
# him        PRON     PRP    pronoun, personal
# in         ADP      IN     conjunction, subordinating or preposition
#
#           SPACE    _SP    whitespace
# no         DET      DT     determiner
# time       NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# He         PRON     PRP    pronoun, personal
# went       VERB     VBD    verb, past tense
# back       ADV      RB     adverb
# to         ADP      IN     conjunction, subordinating or preposition
# his        PRON     PRP$   pronoun, possessive
# work       NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# After      ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# time       NOUN     NN     noun, singular or mass
# he         PRON     PRP    pronoun, personal
# began      VERB     VBD    verb, past tense
# to         PART     TO     infinitival "to"
# wander     VERB     VB     verb, base form
# about      ADP      IN     conjunction, subordinating or preposition
# ,          PUNCT    ,      punctuation mark, comma
# going      VERB     VBG    verb, gerund or present participle
# lippity    NOUN     NN     noun, singular or mass
# --         PUNCT    :      punctuation mark, colon or ellipsis
# lippity    NOUN     NN     noun, singular or mass
# --         PUNCT    :      punctuation mark, colon or ellipsis
# not        PART     RB     adverb
#
#           SPACE    _SP    whitespace
# very       ADV      RB     adverb
# fast       ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# looking    VERB     VBG    verb, gerund or present participle
# all        PRON     DT     determiner
# round      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# Peter      PROPN    NNP    noun, proper singular
# asked      VERB     VBD    verb, past tense
# her        PRON     PRP    pronoun, personal
# the        DET      DT     determiner
# way        NOUN     NN     noun, singular or mass
# to         ADP      IN     conjunction, subordinating or preposition
#
#           SPACE    _SP    whitespace
# the        DET      DT     determiner
# gate       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# but        CCONJ    CC     conjunction, coordinating
# she        PRON     PRP    pronoun, personal
# had        VERB     VBD    verb, past tense
# such       DET      PDT    predeterminer
# a          DET      DT     determiner
# large      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# pea        NOUN     NN     noun, singular or mass
# in         ADP      IN     conjunction, subordinating or preposition
# her        PRON     PRP$   pronoun, possessive
# mouth      NOUN     NN     noun, singular or mass
# that       PRON     WDT    wh-determiner
# she        PRON     PRP    pronoun, personal
# could      AUX      MD     verb, modal auxiliary
# not        PART     RB     adverb
#
#           SPACE    _SP    whitespace
# answer     VERB     VB     verb, base form
# .          PUNCT    .      punctuation mark, sentence closer
# Then       ADV      RB     adverb
# he         PRON     PRP    pronoun, personal
# tried      VERB     VBD    verb, past tense
# to         PART     TO     infinitival "to"
# find       VERB     VB     verb, base form
# his        PRON     PRP$   pronoun, possessive
# way        NOUN     NN     noun, singular or mass
# straight   ADV      RB     adverb
# across     ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# garden     NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# but        CCONJ    CC     conjunction, coordinating
# he         PRON     PRP    pronoun, personal
#
#           SPACE    _SP    whitespace
# became     VERB     VBD    verb, past tense
# more       ADV      RBR    adverb, comparative
# and        CCONJ    CC     conjunction, coordinating
# more       ADV      RBR    adverb, comparative
# puzzled    ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# .          PUNCT    .      punctuation mark, sentence closer
# Peter      PROPN    NNP    noun, proper singular
# thought    VERB     VBD    verb, past tense
# it         PRON     PRP    pronoun, personal
# best       ADJ      JJS    adjective, superlative
# to         PART     TO     infinitival "to"
# go         VERB     VB     verb, base form
# away       ADV      RB     adverb
#
#           SPACE    _SP    whitespace
# without    ADP      IN     conjunction, subordinating or preposition
# speaking   VERB     VBG    verb, gerund or present participle
# to         ADP      IN     conjunction, subordinating or preposition
# her        PRON     PRP    pronoun, personal
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# he         PRON     PRP    pronoun, personal
# had        AUX      VBD    verb, past tense
# heard      VERB     VBN    verb, past participle
# about      ADP      IN     conjunction, subordinating or preposition
# cats       NOUN     NNS    noun, plural
# from       ADP      IN     conjunction, subordinating or preposition
# his        PRON     PRP$   pronoun, possessive
# cousin     NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
#
#           SPACE    _SP    whitespace
# little     ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# Benjamin   PROPN    NNP    noun, proper singular
# Bunny      PROPN    NNP    noun, proper singular
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# But        CCONJ    CC     conjunction, coordinating
# presently  ADV      RB     adverb
# ,          PUNCT    ,      punctuation mark, comma
# as         SCONJ    IN     conjunction, subordinating or preposition
# nothing    PRON     NN     noun, singular or mass
#
#           SPACE    _SP    whitespace
# happened   VERB     VBD    verb, past tense
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# came       VERB     VBD    verb, past tense
# out        ADP      RP     adverb, particle
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# climbed    VERB     VBD    verb, past tense
# upon       SCONJ    IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# wheelbarrow NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# peeped     VERB     VBD    verb, past tense
# over       ADP      RP     adverb, particle
# .          PUNCT    .      punctuation mark, sentence closer
#
#           SPACE    _SP    whitespace
# Peter      PROPN    NNP    noun, proper singular
# got        VERB     VBD    verb, past tense
# down       ADP      RP     adverb, particle
# very       ADV      RB     adverb
# quietly    ADV      RB     adverb
# off        ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# wheelbarrow NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# started    VERB     VBD    verb, past tense
# running    VERB     VBG    verb, gerund or present participle
#
#           SPACE    _SP    whitespace
# as         ADV      RB     adverb
# fast       ADV      RB     adverb
# as         SCONJ    IN     conjunction, subordinating or preposition
# he         PRON     PRP    pronoun, personal
# could      AUX      MD     verb, modal auxiliary
# go         VERB     VB     verb, base form
# ,          PUNCT    ,      punctuation mark, comma
# along      ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# straight   ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# walk       NOUN     NN     noun, singular or mass
# behind     ADP      IN     conjunction, subordinating or preposition
# some       DET      DT     determiner
#
#           SPACE    _SP    whitespace
# black      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# -          PUNCT    HYPH   punctuation mark, hyphen
# currant    NOUN     NN     noun, singular or mass
# bushes     NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# Mr.        PROPN    NNP    noun, proper singular
# McGregor   PROPN    NNP    noun, proper singular
# hung       VERB     VBD    verb, past tense
# up         ADP      RP     adverb, particle
# the        DET      DT     determiner
# little     ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# jacket     NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# the        DET      DT     determiner
# shoes      NOUN     NNS    noun, plural
# for        ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# scare      NOUN     NN     noun, singular or mass
# -          PUNCT    HYPH   punctuation mark, hyphen
# crow       NOUN     NN     noun, singular or mass
#
#           SPACE    _SP    whitespace
# to         PART     TO     infinitival "to"
# frighten   VERB     VB     verb, base form
# the        DET      DT     determiner
# blackbirds NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# His        PRON     PRP$   pronoun, possessive
# mother     NOUN     NN     noun, singular or mass
# was        AUX      VBD    verb, past tense
# busy       ADJ      JJ     adjective (English), other noun-modifier (Chinese)
#
#           SPACE    _SP    whitespace
# cooking    NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# she        PRON     PRP    pronoun, personal
# wondered   VERB     VBD    verb, past tense
# what       PRON     WP     wh-pronoun, personal
# he         PRON     PRP    pronoun, personal
# had        AUX      VBD    verb, past tense
# done       VERB     VBN    verb, past participle
# with       ADP      IN     conjunction, subordinating or preposition
# his        PRON     PRP$   pronoun, possessive
# clothes    NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
# His        PRON     PRP$   pronoun, possessive
# mother     NOUN     NN     noun, singular or mass
# put        VERB     VBD    verb, past tense
# him        PRON     PRP    pronoun, personal
# to         ADP      IN     conjunction, subordinating or preposition
# bed        NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# made       VERB     VBD    verb, past tense
# some       DET      DT     determiner
# camomile   NOUN     NN     noun, singular or mass
# tea        NOUN     NN     noun, singular or mass
# ;          PUNCT    :      punctuation mark, colon or ellipsis
# and        CCONJ    CC     conjunction, coordinating
# she        PRON     PRP    pronoun, personal
# gave       VERB     VBD    verb, past tense
# a          DET      DT     determiner
#
#           SPACE    _SP    whitespace
# dose       NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# it         PRON     PRP    pronoun, personal
# to         ADP      IN     conjunction, subordinating or preposition
# Peter      PROPN    NNP    noun, proper singular
# !          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# But        CCONJ    CC     conjunction, coordinating
# Flopsy     PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# Mopsy      PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# and        CCONJ    CC     conjunction, coordinating
# Cotton     PROPN    NNP    noun, proper singular
# -          PUNCT    HYPH   punctuation mark, hyphen
# tail       NOUN     NN     noun, singular or mass
# had        VERB     VBD    verb, past tense
# bread      NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# milk       NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
#
#           SPACE    _SP    whitespace
# blackberries NOUN     NNS    noun, plural
# for        ADP      IN     conjunction, subordinating or preposition
# supper     NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace

# %% [markdown]
# **3. Provide a frequency list of POS tags from the entire document**

# %%
POS_counts = doc.count_by(spacy.attrs.POS)
for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{5}}: {v}')
# Out:
# 84. ADJ  : 53
# 85. ADP  : 125
# 86. ADV  : 63
# 87. AUX  : 49
# 89. CCONJ: 61
# 90. DET  : 90
# 92. NOUN : 172
# 93. NUM  : 9
# 94. PART : 28
# 95. PRON : 110
# 96. PROPN: 74
# 97. PUNCT: 171
# 98. SCONJ: 19
# 100. VERB : 135
# 103. SPACE: 99

# %% [markdown]
# **4. CHALLENGE: What percentage of tokens are nouns?**<br>
# HINT: the attribute ID for 'NOUN' is 91

# %%
sum = 0
for k,v in sorted(POS_counts.items()):
    sum += v
print(f'166 / {sum} = {166/sum*100}%')
# Out:
# 166 / 1258 = 13.195548489666137%

# %% [markdown]
# **5. Display the Dependency Parse for the third sentence**

# %%
# Render the dependency parse immediately inside Jupyter:
sentences = list(doc.sents)
third_sent = sentences[2]
displacy.render(third_sent, style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="84da05e004ca43c78d105c1f478a6556-0" class="displacy" width="2250" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">Mother</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">sand-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">bank,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">underneath</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">root</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">fir-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">tree.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84da05e004ca43c78d105c1f478a6556-0-0" stroke-width="2px" d="M70,277.0 C70,222.0 140.0,222.0 140.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84da05e004ca43c78d105c1f478a6556-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,279.0 L62,267.0 78,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84da05e004ca43c78d105c1f478a6556-0-1" stroke-width="2px" d="M180,277.0 C180,222.0 250.0,222.0 250.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84da05e004ca43c78d105c1f478a6556-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250.0,279.0 L258.0,267.0 242.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84da05e004ca43c78d105c1f478a6556-0-2" stroke-width="2px" d="M400,277.0 C400,222.0 470.0,222.0 470.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84da05e004ca43c78d105c1f478a6556-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,279.0 L392,267.0 408,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84da05e004ca43c78d105c1f478a6556-0-3" stroke-width="2px" d="M290,277.0 C290,167.0 475.0,167.0 475.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84da05e004ca43c78d105c1f478a6556-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M475.0,279.0 L483.0,267.0 467.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84da05e004ca43c78d105c1f478a6556-0-4" stroke-width="2px" d="M180,277.0 C180,112.0 590.0,112.0 590.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84da05e004ca43c78d105c1f478a6556-0-4" class="displacy-label" startOffset="50%" side="left"

# %% [markdown]
# **6. Show the first two named entities from Beatrix Potter's *The Tale of Peter Rabbit* **

# %%
x = 0
for ent in doc.ents:
    x += 1
    print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
    if x == 2:
        break
# Out:
# The Tale of Peter Rabbit - WORK_OF_ART - Titles of books, songs, etc.
# Beatrix Potter - PERSON - People, including fictional

# %% [markdown]
# **7. How many sentences are contained in *The Tale of Peter Rabbit*?**

# %%
len(sentences)
# Out:
# 55

# %% [markdown]
# **8. CHALLENGE: How many sentences contain named entities?**

# %%
total = 0
for sentence in doc.sents:
    if sentence.ents:
        total += 1
total
# Out:
# 35

# %% [markdown]
# **9. CHALLENGE: Display the named entity visualization for `list_of_sents[0]` from the previous problem**

# %%
displacy.render(sentences[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).<br><br></div></span>
